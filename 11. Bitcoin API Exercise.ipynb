# %% [markdown]
# # Bitcoin API

# %% [markdown]
# APIs are important source of information. In this exercise we will use popular financial API https://www.alphavantage.co. Although all API endpionts are different the process of fetching data will be relatively similar no metter if you use Bloomberg or Alphavantage or any other source of information.

# %% [markdown]
# Hint: If you get timout error running this example make sure you switch off VPN or Fire Wall and you use regular, not a corporate WiFi network. Also, you could run this example in free cloud https://colab.research.google.com

# %% [markdown]
# # 1. Import all the libriaries

# %% [markdown]
# Hint: In addition to Pandas and Matplotlib you will need requests https://docs.python-requests.org/en/latest/

# %%
import requests

# %% [markdown]
# # 2. To use an API you would need to obtain and API Key, get one here https://www.alphavantage.co/support/#api-key

# %% [markdown]
# Hint: copy and paste the key into "place your API Key here", API Key is very sensative and should be stored as a string

# %%
API_KEY = "place your API Key here"

# %% [markdown]
# # 3. In the documentation you can find and choose an API endpoint you would want to use https://www.alphavantage.co/documentation/

# %% [markdown]
# Hint: In this example we will use the folowing end point

# %%
url = "https://www.alphavantage.co/query?function=DIGITAL_CURRENCY_DAILY&symbol=BTC&market=USD&apikey={}"

# %% [markdown]
# # 4. Use the string method format() to pass the API_Key into the defined above url

# %% [markdown]
# Hint: path = url.format(API_KEY)

# %%
# Out:
# 'https://www.alphavantage.co/query?function=DIGITAL_CURRENCY_DAILY&symbol=BTC&market=USD&apikey=4ISYFY5FKIA7Y1NU'

# %% [markdown]
# # 5. Use requests.get() to fetch the data from the API

# %% [markdown]
# ```
# Hint: rawdata should return response 200
# rawdata = requests.get(path)
# ```

# %%
# Out:
# <Response [200]>

# %% [markdown]
# # 6. Use method json() to parse rawdata in JSON format

# %%
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices and Volumes for Digital Currency',
#   '2. Digital Currency Code': 'BTC',
#   '3. Digital Currency Name': 'Bitcoin',
#   '4. Market Code': 'USD',
#   '5. Market Name': 'United States Dollar',
#   '6. Last Refreshed': '2022-02-17 00:00:00',
#   '7. Time Zone': 'UTC'},
#  'Time Series (Digital Currency Daily)': {'2022-02-17': {'1a. open (USD)': '43873.56000000',
#    '1b. open (USD)': '43873.56000000',
#    '2a. high (USD)': '43951.59000000',
#    '2b. high (USD)': '43951.59000000',
#    '3a. low (USD)': '43822.28000000',
#    '3b. low (USD)': '43822.28000000',
#    '4a. close (USD)': '43917.45000000',
#    '4b. close (USD)': '43917.45000000',
#    '5. volume': '421.82359000',
#    '6. market cap (USD)': '421.82359000'},
#   '2022-02-16': {'1a. open (USD)': '44544.85000000',
#    '1b. open (USD)': '44544.85000000',
#    '2a. high (USD)': '44549.97000000',
#    '2b. high (USD)': '44549.97000000',
#    '3a. low (USD)': '43307.00000000',
# ...

# %% [markdown]
# # 7. Use function type() to check the data type of the data object, returned by API

# %%
# Out:
# dict

# %% [markdown]
# # 8. Use the dictionary method keys() to identify all the keys in the data

# %%
# Out:
# dict_keys(['Meta Data', 'Time Series (Digital Currency Daily)'])

# %% [markdown]
# # 9. Grab the desired information from the data dictionary by 'Time Series (Digital Currency Daily)' key and save it with variable "d"

# %% [markdown]
# # 10. Initialize a new Data Frame with the pd.DataFrame() function

# %% [markdown]
# # 11. Use the DataFrame method from_dict() to convert d dictionary into the DataFrame

# %% [markdown]
# Hint: use keyword orient="index" in the from_dict() method

# %%
# Out:
#             1a. open (USD)  1b. open (USD)  2a. high (USD)  2b. high (USD)  \
# 2022-02-17  43873.56000000  43873.56000000  43951.59000000  43951.59000000
# 2022-02-16  44544.85000000  44544.85000000  44549.97000000  44549.97000000
# 2022-02-15  42535.94000000  42535.94000000  44751.40000000  44751.40000000
# 2022-02-14  42053.65000000  42053.65000000  42842.40000000  42842.40000000
# 2022-02-13  42217.87000000  42217.87000000  42760.00000000  42760.00000000
#
#              3a. low (USD)   3b. low (USD) 4a. close (USD) 4b. close (USD)  \
# 2022-02-17  43822.28000000  43822.28000000  43917.45000000  43917.45000000
# 2022-02-16  43307.00000000  43307.00000000  43873.56000000  43873.56000000
# 2022-02-15  42427.03000000  42427.03000000  44544.86000000  44544.86000000
# 2022-02-14  41550.56000000  41550.56000000  42535.94000000  42535.94000000
# 2022-02-13  41870.00000000  41870.00000000  42053.66000000  42053.66000000
#
#                  5. volume 6. market cap (USD)
# ...

# %% [markdown]
# # 12. Set df.index as "Date" column in df

# %% [markdown]
# # 13. Slice colums "Date" and "4a. close (USD)" and save them as a new DataFrame under name "bc"

# %% [markdown]
# Hint: use method copy() to save new bc DataFrame as totaly new object

# %%
# Out:
#                   Date 4a. close (USD)
# 2022-02-17  2022-02-17  43917.45000000
# 2022-02-16  2022-02-16  43873.56000000
# 2022-02-15  2022-02-15  44544.86000000
# 2022-02-14  2022-02-14  42535.94000000
# 2022-02-13  2022-02-13  42053.66000000

# %% [markdown]
# # 14. Use info() method to see Data Types of the values in bc DataFarame

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 2022-02-17 to 2019-05-25
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             1000 non-null   object
#  1   4a. close (USD)  1000 non-null   object
# dtypes: object(2)
# memory usage: 23.4+ KB

# %% [markdown]
# # 15. Convert the values in the bc "4a. close (USD)" columnt to numeric values using function pd.to_numeric() and save results in a new column "Close"

# %% [markdown]
# Hint: see an example here https://pandas.pydata.org/docs/reference/api/pandas.to_numeric.html

# %% [markdown]
# # 16. Convert the values in the bc "Date" columnt to datetime objects using function pd.to_datetime() and save results under the same name "Date"

# %% [markdown]
# Hint: see an example here https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html

# %% [markdown]
# # 17. Plot the bc "Close" and "Date" columns as a line plot

# %%
# Out:
# Text(0.5, 1.0, 'Bitcoin USD')
